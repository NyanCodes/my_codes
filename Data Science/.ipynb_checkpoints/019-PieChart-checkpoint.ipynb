# %%
# %matplotlib inline
import matplotlib.pyplot as plt

data = [25, 75]
plt.axis('equal')
plt.pie(data)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

data = [100, 50, 150]
plt.axis('equal')
plt.pie(data)
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

data = [100, 50, 150]

lbl = ['Coffee', 'Tea', 'Milk']
col = ['brown', 'orange', 'gray']
spl = [0, 0.1, 0] # explode

plt.pie(data, labels = lbl, colors = col, explode = spl, shadow = True, autopct = '%%%')
plt.title('Drink Distribution')

plt.axis('equal')
plt.show()
